# %%
import numpy as np
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
imagen = imread("imagenh.png")
imagen.shape
imshow(imagen)

# %%
grices = np.zeros( (1440,1920,3) )
negativo = np.zeros( (1440,1920,3) )

# %%
for f in range (1439):
    for c in range (1919):
        valor = 0
        valor = (0.3*imagen[f][c][0])+(0.59*imagen[f][c][1])+(0.11*imagen[f][c][2])
        grices[f][c][0]= valor
        grices[f][c][1]= valor
        grices[f][c][2]= valor

# %%
imshow(grices)

# %%
for f in range (1439):
    for c in range (1919):
        negativo[f][c][0]= 1-imagen[f][c][0]
        negativo[f][c][1]= 1-imagen[f][c][1]
        negativo[f][c][2]= 1-imagen[f][c][2]

# %%
imshow(negativo)
