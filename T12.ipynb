# %%
import numpy as np
import matplotlib.pyplot as plt
# %pylab inline
from scipy.optimize import curve_fit
import scipy.integrate as integrate
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
#Constantes:
lista = linspace(-2.5, 2.5, 20)
reales=[]

# %%
def f (v):
    return np.e**(-v**2)
x = linspace(-2.5,2.5,31416) 
exp = f(x)
plot(x,exp)

# %%
minx, maxx = -2, 2
miny, maxy = 0, amax(exp)

# %%
rx = random.rand(10000)*(maxx-minx)+minx
ry = random.rand(10000)*(maxy-miny)+miny

# %%
scatter (rx,ry,alpha = 0.2, color = "blue")
xlim(-2.5,2.5)
ylim(0, maxy)
# Out:
# (0, 0.9999999936670525)

# %%
var = where (f(rx)-ry > 0.0)
scatter(rx[var], ry[var], alpha = 0.5)
ylim(miny, maxy)
# Out:
# (0, 0.9999999936670525)

# %%
def lim (x):
    return (amax(f(x))-miny)*(x-minx)
def antiEva (l):
    return lim(l)*(size(var)/(1.0*size(ry)))
def integralesReales ():
    for var in lista:
        reales.append(integrate.quad(lambda x: antiEva(var) , -2.5, var))
print reales
# Out:
# [-2.5        -2.23684211 -1.97368421 -1.71052632 -1.44736842 -1.18421053
#  -0.92105263 -0.65789474 -0.39473684 -0.13157895  0.13157895  0.39473684
#   0.65789474  0.92105263  1.18421053  1.44736842  1.71052632  1.97368421
#   2.23684211  2.5       ]

# %%
#inte = (maxy-miny)*(maxx-minx)

# %%
#inte*(size(var)/(1.0*size(ry))
#print antiEva(size(var)) 
#def antiEva (l):
#    return inte*(size(var)/(1.0*size(ry)))
#integrate.quad(lambda x: antiEva(v) , 0, 4.5)
#def error (f):
#    if antiEva(f)-
